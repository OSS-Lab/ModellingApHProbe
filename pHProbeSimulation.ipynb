# %%
from __future__ import print_function
from fenics import *
import os
from mshr import *
import numpy as np
import matplotlib.pyplot as plt
from dolfin import *
import numpy as np
import time
from math import *
import sympy as sym

from numpy.random import rand

from operator import mul
from functools import reduce

from scipy.integrate import odeint

from reaction_diffusion_symbolic_defs import *

from reaction_diffusion_source_functions import *

# %matplotlib inline
sym.init_printing()

# %% [markdown]
# # Heat diffusion with rectangular source

# %%
cellSources = [
]

boxSources =[
    {"location":[(-1.0,1.5),(1.0,1.7)], "function":["oscillatory"], "parameters":[{"amplitude":1.0,"frequency":1.0,"phase":0.0}]}   
]




T = 1000          # final time
num_steps = 500  # number of time steps
dt = T / num_steps # time step size
solutionFileName = 'pHProbeSimulationOsc/solution.pvd'

nx = ny = 300
mesh = RectangleMesh(Point(-2, -2), Point(2, 2), nx, ny)

plotBoxFunctions(boxSources,T,dt)
plotCellFunctions(cellSources,T,dt)
pHProbeSimulation(cellSources,boxSources,T,num_steps,dt,solutionFileName, mesh)

# %%
cellSources = [
]

boxSources =[
    {"location":[(-1.0,1.5),(1.0,1.7)], "function":["lagPulse"], "parameters":[{"amplitude":10.0,"duration":(1.5,7.5), "lag":1.0}]}   
]

T = 1000            # final time
num_steps = 500   # number of time steps
dt = T / num_steps # time step size
solutionFileName = 'pHProbeSimulationLagPulse/solution.pvd'

nx = ny = 300
mesh = RectangleMesh(Point(-2, -2), Point(2, 2), nx, ny)

plotBoxFunctions(boxSources,T,dt)
plotCellFunctions(cellSources,T,dt)
pHProbeSimulation(cellSources,boxSources,T,num_steps,dt,solutionFileName, mesh)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fd6ee0599fd6> in <module>
#      16 plotBoxFunctions(boxSources,T,dt)
#      17 plotCellFunctions(cellSources,T,dt)
# ---> 18 pHProbeSimulation(cellSources,boxSources,T,num_steps,dt,solutionFileName, mesh)
#
# ~/Documents/JupyterNotebook/Fenics/reaction_diffusion_symbolic_defs.py in pHProbeSimulation(cellSources, boxSources, T, num_steps, dt, solutionFileName, mesh)
#    1031
#    1032         # Compute solution
# -> 1033         solve(a == L, u, bc)
#    1034
#    1035         # Save to file and plot solution
#
# /usr/lib/petsc/lib/python3/dist-packages/dolfin/fem/solving.py in solve(*args, **kwargs)
#     231     # tolerance)
#     232     elif isinstance(args[0], ufl.classes.Equation):
# --> 233         _solve_varproblem(*args, **kwargs)
#     234
# ...

# %%
cellSources = [
]

boxSources =[
    {"location":[(-1.0,1.5),(1.0,1.7)], "function":["lagPulse"], "parameters":[{"amplitude":10.0,"duration":(1.5,7.5), "lag":1.0}]}   
]

domain=[
    {"diffusionCoeffs":0.01}
]

subRegionByLocation=[
    {"yValue":-1,"diffusionFactor":0.1}
]

T = 1000            # final time
num_steps = 500   # number of time steps
dt = T / num_steps # time step size
solutionFileName = 'pHProbeSimulationLagPulseDiffInhibit/solution.pvd'

nx = ny = 300
mesh = RectangleMesh(Point(-2, -2), Point(2, 2), nx, ny)

plotBoxFunctions(boxSources,T,dt)
plotCellFunctions(cellSources,T,dt)
pHProbeCellSimulation(cellSources,boxSources,domain,subRegionByLocation,T,num_steps,dt,solutionFileName, mesh)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
